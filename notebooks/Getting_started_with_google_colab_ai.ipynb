# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohitpal12345/pythonpractice/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(1,11):
  print("rohit")
# Out:
# rohit
# rohit
# rohit
# rohit
# rohit
# rohit
# rohit
# rohit
# rohit
# rohit
